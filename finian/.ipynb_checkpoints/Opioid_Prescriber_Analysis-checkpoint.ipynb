# %% [markdown]
# # Opioid Prescriber Analysis
#
# #### This notebook will explore the Opioid prescribers based on Medicare data from data.cms.gov. Then, it will use the Google Maps API to create a heat map of the Opioid prescriptions over the US.
#
# Technologies:
# * Google API
# * Socrata
# * Pandas

# %%
# import dependencies
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cms.gov", "dLbTEKbMpc1G4L7fCsOvHvATT")
#client = Socrata("data.cms.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cms.gov,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# %%
# First n results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
opioid_prescriber_results_2016 = client.get("mm6p-bnrx", limit=2000000)

# Convert to pandas DataFrame
results_2016_df = pd.DataFrame.from_records(opioid_prescriber_results_2016)
results_2016_df.head()
# Out:
#   extended_release_opioid_claims extended_release_opioid_prescribing_rate  \
# 0                            NaN                                      NaN
# 1                             63                           0.062749003984
# 2                              0                                        0
# 3                              0                                      NaN
# 4                              0                                        0
#
#           npi nppes_provider_first_name nppes_provider_last_name  \
# 0  1003000126                   ARDALAN                ENKESHAFI
# 1  1003000142                    RASHID                   KHALIL
# 2  1003000167                     JULIO                  ESCOBAR
# 3  1003000282                     ROSIE                BLAKEMORE
# 4  1003000407                     DAVID                  GIRARDI
#
#   nppes_provider_state nppes_provider_zip_code opioid_claim_count  \
# 0                   MD                   21502                 23
# 1                   OH                   43623               1004
# 2                   NV                   89403                 11
# 3                   TN                   37243                NaN
# 4                   PA                   15825                 17
#
#   percent_opioid_claims specialty_description total_claim_count
# 0        0.042201834862     Internal Medicine               545
# 1         0.57934218119        Anesthesiology              1733
# 2         0.22448979592               Dentist                49
# 3                   NaN    Nurse Practitioner               146
# 4        0.007640449438       Family Practice              2225

# %%
# sort the dataframe by top opioid prescriber (i.e. prescribers with
# highest 'opioid_claim_count')
sorted_results_2016 = results_2016_df.sort_values(by="opioid_claim_count", ascending=False)
sorted_results_2016.head()
# Out:
#        extended_release_opioid_claims  \
# 672265                            107
# 547042                             80
# 999453                             22
# 474256                            NaN
# 534227                             24
#
#        extended_release_opioid_prescribing_rate         npi  \
# 672265                            0.10710710711  1598729055
# 547042                            0.08008008008  1487639910
# 999453                           0.022022022022  1881660942
# 474256                                      NaN  1417963778
# 534227                           0.024024024024  1477546976
#
#        nppes_provider_first_name nppes_provider_last_name  \
# 672265               CHRISTOPHER                    SMITH
# 547042                   WILLIAM                   GETSON
# 999453                     JAMES                   HARVEY
# 474256                  MAURICIO                 BERMUDEZ
# 534227                   CHARLES                  HORSLEY
#
#        nppes_provider_state nppes_provider_zip_code opioid_claim_count  \
# 672265                   PA                   19610                999
# 547042                   PA                   16412                999
# 999453                   MS                   38801                999
# 474256                   FL                   33607                999
# 534227                   OH                   45036                999
#
#        percent_opioid_claims specialty_description total_claim_count
# 672265        0.064676939013     Internal Medicine             15446
# 547042        0.060158978682       Family Practice             16606
# 999453        0.051084066271     Internal Medicine             19556
# 474256        0.047968885048       Family Practice             20826
# 534227        0.060970399756       Family Practice             16385

# %%
# create longitude and latitude columns to dump coordinates from Google API
# into in order to create heat map from
sorted_results_2016["lat"] = ""
sorted_results_2016["lng"] = ""
# Out:
# 1131550
